# %% [markdown]
# <a href="https://colab.research.google.com/github/CaylibHahn/CaylibHahn/blob/main/reinforcement_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install aima3
